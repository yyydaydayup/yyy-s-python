# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,20,)
y = np.sin(x)
plt.plot(x,y)

# %%
plt.plot(x,y,marker='o',markerfacecolor='red',markersize=8,markeredgecolor='green',markeredgewidth=2)

# %%
y = np.sin(np.arange(20))
plt.plot(y,marker='o')
plt.annotate("(0,0)",xy=(0,0),xytext=(-0.5,-0.8),arrowprops={"width":10,"headwidth":16,"headlength":20,"shrink":0.3,"facecolor":"r","edgecolor":"y"})
# Out:
# Text(-0.5, -0.8, '(0,0)')

# %%
ax = plt.subplot(111)

x = np.arange(0.0, 5.0, 0.01)
y = np.cos(2*np.pi*t)
line, = plt.plot(x, y,linewidth=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
arrowprops=dict(facecolor='black',shrink=0.05),
)

plt.ylim(-2, 2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-2604b97c4965> in <module>
#       2
#       3 x = np.arange(0.0, 5.0, 0.01)
# ----> 4 y = np.cos(2*np.pi*t)
#       5 line, = plt.plot(x, y,linewidth=2)
#       6
#
# NameError: name 't' is not defined
